# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![title.png](attachment:49b97f3d-142a-4bff-a516-56c9d55ce440.png)

# %% [markdown]
# practice3: In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:58aea6dc-e7f7-44a9-b227-8824493e30db.png)

# %% [markdown]
# pratice10    ***Objectives:***
# + List popular languages for Data Science
# + List libraries for Data Science
# + List tools for Data Science

# %% [markdown]
# ![10-objectives.png](attachment:8b696456-f7ea-4462-afe6-211001afc0dc.png)

# %% [markdown]
# practice4: Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Julia
# 4. SQL![image.png](attachment:c8372f19-0634-4233-8994-14749853999e.png)

# %% [markdown]
# ![4-dslanguages](attachment:6ce8c146-6f82-402b-a70f-aaf3b1734a9c.png)

# %% [markdown]
# practice5:Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Scikit-learn
# 4. TensorFlow
# 5. Keras

# %% [markdown]
# ![5-dslibraries.png](attachment:0bd5f922-248e-4755-a74e-827ca8a4f9de.png)

# %% [markdown]
# practice6: Data Science Tools:
# 1. Jupyter Notebook
# 2. RStudio
# 3. Apache Zeppelin

# %% [markdown]
# ![6-dstools.png](attachment:33849abd-12e2-48d9-9d9d-82bec7b0d9bd.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:dd3c0180-ccb2-4a9f-bfa3-df394968e035.png)

# %%
 # This a simple arithmetic expression to mutiply then add integers
print((3*4)+5)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:2c623da5-c6f1-4bbe-9f3e-77329daa271b.png)

# %%
# This will convert 200 minutes to hours by diving by 60
print(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:53cf6b7a-496e-4913-8a03-8e29a5b67042.png)

# %% [markdown]
# ## homework  Qi An

# %% [markdown]
# ![11-authordetails.png](attachment:8687640a-594d-480f-b32b-23e3ac814db7.png)
